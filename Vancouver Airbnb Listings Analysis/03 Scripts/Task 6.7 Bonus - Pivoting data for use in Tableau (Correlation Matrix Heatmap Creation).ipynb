# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Define path
path = 'C:/Users/kaymi/OneDrive/Desktop/Career Foundry/Data Immersion/Achievement 6 - Advanced Data Analytics'

# %%
# Import data
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'tableau_matrix.csv'))

# %%
df.head()
# Out:
#    Unnamed: 0  listing_id  price  minimum_nights  number_of_reviews  \
# 0           0       13188    150               3                260
# 1           1       13358    227               1                454
# 2           2       13490    150              30                 98
# 3           3       14267    150               3                 34
# 4           4       14424    134              30                266
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               1.61                               2               150
# 1               2.88                               1               247
# 2               0.67                               1               121
# 3               0.22                               1                 0
# 4               1.64                               4               187
#
#    number_of_reviews_ltm
# 0                      4
# 1                     19
# 2                      5
# ...

# %%
#Drop unnamed column
df = df.drop(columns=["Unnamed: 0"])

# %%
df.head()
# Out:
#    listing_id  price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0       13188    150               3                260               1.61
# 1       13358    227               1                454               2.88
# 2       13490    150              30                 98               0.67
# 3       14267    150               3                 34               0.22
# 4       14424    134              30                266               1.64
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                               2               150                      4
# 1                               1               247                     19
# 2                               1               121                      5
# 3                               1                 0                      0
# 4                               4               187                      7

# %%
df.dtypes
# Out:
# listing_id                          int64
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# dtype: object

# %%
#Updating listing id data type to string
df['listing_id'] = df['listing_id'].astype('str')

# %%
df.dtypes
# Out:
# listing_id                         object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# dtype: object

# %%
# Storing measure/numerical column names in "measure_cols" list
measure_cols = [i for i in df.select_dtypes(include=np.number).columns]

# %%
# Storing categorical column names in "cat_cols" list
cat_cols = [i for i in df.columns if i not in measure_cols]

# %%
measure_cols
# Out:
# ['price',
#  'minimum_nights',
#  'number_of_reviews',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm']

# %%
cat_cols
# Out:
# ['listing_id']

# %%
df.melt(id_vars=cat_cols)
# Out:
#                listing_id               variable  value
# 0                   13188                  price  150.0
# 1                   13358                  price  227.0
# 2                   13490                  price  150.0
# 3                   14267                  price  150.0
# 4                   14424                  price  134.0
# ...                   ...                    ...    ...
# 41498  909442000000000000  number_of_reviews_ltm    0.0
# 41499  909450000000000000  number_of_reviews_ltm    0.0
# 41500  909475000000000000  number_of_reviews_ltm    0.0
# 41501  909539000000000000  number_of_reviews_ltm    0.0
# 41502  909578000000000000  number_of_reviews_ltm    0.0
#
# [41503 rows x 3 columns]

# %%
# Saving pivoted data
df.melt(id_vars=cat_cols).to_csv(os.path.join(path, '02 Data','Prepared Data','correlation_tab.csv'))

# %%
# Import data
df_clusters = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'vacation_listings_subset.csv'))

# %%
df_clusters.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  listing_id  \
# 0             0           0       13188
# 1             1           1       13358
# 2             2           2       13490
# 3             3           3       14267
# 4             4           4       14424
#
#                                         listing_name  host_id       host_name  \
# 0  Rental unit in Vancouver · ★4.83 · Studio · 2 ...    51466     Family Guns
# 1  Condo in Vancouver · ★4.68 · 1 bedroom · 1 bed...    52116            Lynn
# 2  Rental unit in Vancouver · ★4.92 · 1 bedroom ·...    52467            Iris
# 3  Home in Vancouver · ★4.76 · 1 bedroom · 2 beds...    56030  Peter & Alison
# 4  Guest suite in Vancouver · ★4.69 · 1 bedroom ·...    56709     Samantha Jo
#
#               neighbourhood  latitude  longitude        room_type  ...  \
# 0                Riley Park  49.24773 -123.10509  Entire home/apt  ...
# 1                  West End  49.28201 -123.12669  Entire home/apt  ...
# ...
